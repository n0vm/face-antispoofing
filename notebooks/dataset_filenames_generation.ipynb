# %% [markdown]
# # Генерация названий файлов датасета

# %% [markdown]
# ## Параметры съемки

# %% [markdown]
# 1. Модели:
#     * a)	Буриев Артур
#     * b)	Тарасов Александр
#     * c)	Гладченко Андрей
#     * d)    Конюхов Глеб
#     * e)    Асадулин Родион
#     * f)    Мирманов Лукман
#     * g)    Козлов Семен
#
# 2. Варианты расстояний до объекта:
#     * a)	0.5-0.7 м
#     * b)	1 м
#     * c)	1.2-1.5 м
#
#
# 3. Варианты положений центра лица (нос) относительно квадратов кадра:
# <table>
#     <tr><td>1a</td>	<td>1b</td>	<td>1c</td></tr>
#     <tr><td>2a</td>	<td>2b</td>	<td>2c</td></tr>
#     <tr><td>3a</td>	<td>3b</td>	<td>3c</td></tr>
# </table>
#
# 4. Варианты фона (один для каждой модели):
#     * a)	равномерный фон – стена
#     * b)	неравномерный фон – стена + объекты на заднем плане
#     * c)	равномерный фон с контрастными тепловыми объектами – окно/батарея в кадре
#     * d)	неравномерный фон (объекты на заднем плане) с контрастными тепловыми объектами (окно/батарея)
#
#
# 5. Варианты лица:
#     * a) истинное лицо
#         * a1) серьезное выражение лица
#         * a2) с улыбкой (рот прикрыт)
#         * a3) с улыбкой (рот приоткрыт)
#         * a4) хмурое/сердитое выражение
#     * b) лицо с прямоугольной маской
#     * c) лицо с бумажной маской по контуру лица
#     * d) планшет с фотографией
#     * e) латексная маска
#
#
# 6. Варианты снимающего устройства:
#     * a)	камера мобильного телефона
#     * b)	Seek Thermal (тепловизор)

# %% [markdown]
# ### Импорт необходимых библиотек

# %%
import sys

sys.path.insert(1, "../")

from src.data.dataset_filenames import generate_filenames

# %% [markdown]
# ### Эксперимент №1.1

# %%
filenames_exp_11 = generate_filenames(
    {
        "expnum": ["exp11"],
        "models": ["a", "b"],
        "distances": ["a", "b", "c"],
        "positions": ["1a", "1b", "1c", "2a", "2b", "2c", "3a", "3b", "3c"],
        "background": ["x"],
        "faces": ["a1", "b"],
        "devices": ["a", "b"],
    }
)

# %%
filenames_exp_11
# Out:
# ['exp11_a_a_1a_x_a1_a.jpg',
#  'exp11_a_a_1a_x_a1_b.jpg',
#  'exp11_a_a_1a_x_b_a.jpg',
#  'exp11_a_a_1a_x_b_b.jpg',
#  'exp11_a_a_1b_x_a1_a.jpg',
#  'exp11_a_a_1b_x_a1_b.jpg',
#  'exp11_a_a_1b_x_b_a.jpg',
#  'exp11_a_a_1b_x_b_b.jpg',
#  'exp11_a_a_1c_x_a1_a.jpg',
#  'exp11_a_a_1c_x_a1_b.jpg',
#  'exp11_a_a_1c_x_b_a.jpg',
#  'exp11_a_a_1c_x_b_b.jpg',
#  'exp11_a_a_2a_x_a1_a.jpg',
#  'exp11_a_a_2a_x_a1_b.jpg',
#  'exp11_a_a_2a_x_b_a.jpg',
#  'exp11_a_a_2a_x_b_b.jpg',
#  'exp11_a_a_2b_x_a1_a.jpg',
#  'exp11_a_a_2b_x_a1_b.jpg',
#  'exp11_a_a_2b_x_b_a.jpg',
#  'exp11_a_a_2b_x_b_b.jpg',
#  'exp11_a_a_2c_x_a1_a.jpg',
#  'exp11_a_a_2c_x_a1_b.jpg',
#  'exp11_a_a_2c_x_b_a.jpg',
#  'exp11_a_a_2c_x_b_b.jpg',
#  'exp11_a_a_3a_x_a1_a.jpg',
#  'exp11_a_a_3a_x_a1_b.jpg',
#  'exp11_a_a_3a_x_b_a.jpg',
#  'exp11_a_a_3a_x_b_b.jpg',
#  'exp11_a_a_3b_x_a1_a.jpg',
#  'exp11_a_a_3b_x_a1_b.jpg',
#  'exp11_a_a_3b_x_b_a.jpg',
#  'exp11_a_a_3b_x_b_b.jpg',
#  'exp11_a_a_3c_x_a1_a.jpg',
# ...

# %%
len(filenames_exp_11)
# Out:
# 216

# %% [markdown]
# ### Эксперимент №1.2

# %%
filenames_exp_12 = generate_filenames(
    {
        "expnum": ["exp12"],
        "models": ["a", "b", "c", "d"],
        "distances": ["a", "b"],
        "positions": ["2b", "3c"],
        "background": ["x"],
        "faces": ["a1", "b", "c"],
        "devices": ["a", "b"],
    }
)

# %%
filenames_exp_12
# Out:
# ['exp12_a_a_2b_x_a1_a.jpg',
#  'exp12_a_a_2b_x_a1_b.jpg',
#  'exp12_a_a_2b_x_b_a.jpg',
#  'exp12_a_a_2b_x_b_b.jpg',
#  'exp12_a_a_2b_x_c_a.jpg',
#  'exp12_a_a_2b_x_c_b.jpg',
#  'exp12_a_a_3c_x_a1_a.jpg',
#  'exp12_a_a_3c_x_a1_b.jpg',
#  'exp12_a_a_3c_x_b_a.jpg',
#  'exp12_a_a_3c_x_b_b.jpg',
#  'exp12_a_a_3c_x_c_a.jpg',
#  'exp12_a_a_3c_x_c_b.jpg',
#  'exp12_a_b_2b_x_a1_a.jpg',
#  'exp12_a_b_2b_x_a1_b.jpg',
#  'exp12_a_b_2b_x_b_a.jpg',
#  'exp12_a_b_2b_x_b_b.jpg',
#  'exp12_a_b_2b_x_c_a.jpg',
#  'exp12_a_b_2b_x_c_b.jpg',
#  'exp12_a_b_3c_x_a1_a.jpg',
#  'exp12_a_b_3c_x_a1_b.jpg',
#  'exp12_a_b_3c_x_b_a.jpg',
#  'exp12_a_b_3c_x_b_b.jpg',
#  'exp12_a_b_3c_x_c_a.jpg',
#  'exp12_a_b_3c_x_c_b.jpg',
#  'exp12_b_a_2b_x_a1_a.jpg',
#  'exp12_b_a_2b_x_a1_b.jpg',
#  'exp12_b_a_2b_x_b_a.jpg',
#  'exp12_b_a_2b_x_b_b.jpg',
#  'exp12_b_a_2b_x_c_a.jpg',
#  'exp12_b_a_2b_x_c_b.jpg',
#  'exp12_b_a_3c_x_a1_a.jpg',
#  'exp12_b_a_3c_x_a1_b.jpg',
#  'exp12_b_a_3c_x_b_a.jpg',
#  'exp12_b_a_3c_x_b_b.jpg',
# ...

# %%
len(filenames_exp_12)
# Out:
# 96

# %% [markdown]
# ### Эксперимент №2.1

# %%
filenames_exp_21 = generate_filenames(
    {
        "expnum": ["exp21"],
        "models": ["e"],
        "distances": ["a", "b", "c"],
        "positions": ["1a", "1b", "1c", "2a", "2b", "2c", "3a", "3b", "3c"],
        "background": ["x"],
        "faces": ["a1", "a2", "a3", "a4", "b", "c", "d", "e"],
        "devices": ["a", "b"],
    }
)

# %%
filenames_exp_21
# Out:
# ['exp21_e_a_1a_x_a1_a.jpg',
#  'exp21_e_a_1a_x_a1_b.jpg',
#  'exp21_e_a_1a_x_a2_a.jpg',
#  'exp21_e_a_1a_x_a2_b.jpg',
#  'exp21_e_a_1a_x_a3_a.jpg',
#  'exp21_e_a_1a_x_a3_b.jpg',
#  'exp21_e_a_1a_x_a4_a.jpg',
#  'exp21_e_a_1a_x_a4_b.jpg',
#  'exp21_e_a_1a_x_b_a.jpg',
#  'exp21_e_a_1a_x_b_b.jpg',
#  'exp21_e_a_1a_x_c_a.jpg',
#  'exp21_e_a_1a_x_c_b.jpg',
#  'exp21_e_a_1a_x_d_a.jpg',
#  'exp21_e_a_1a_x_d_b.jpg',
#  'exp21_e_a_1a_x_e_a.jpg',
#  'exp21_e_a_1a_x_e_b.jpg',
#  'exp21_e_a_1b_x_a1_a.jpg',
#  'exp21_e_a_1b_x_a1_b.jpg',
#  'exp21_e_a_1b_x_a2_a.jpg',
#  'exp21_e_a_1b_x_a2_b.jpg',
#  'exp21_e_a_1b_x_a3_a.jpg',
#  'exp21_e_a_1b_x_a3_b.jpg',
#  'exp21_e_a_1b_x_a4_a.jpg',
#  'exp21_e_a_1b_x_a4_b.jpg',
#  'exp21_e_a_1b_x_b_a.jpg',
#  'exp21_e_a_1b_x_b_b.jpg',
#  'exp21_e_a_1b_x_c_a.jpg',
#  'exp21_e_a_1b_x_c_b.jpg',
#  'exp21_e_a_1b_x_d_a.jpg',
#  'exp21_e_a_1b_x_d_b.jpg',
#  'exp21_e_a_1b_x_e_a.jpg',
#  'exp21_e_a_1b_x_e_b.jpg',
#  'exp21_e_a_1c_x_a1_a.jpg',
# ...

# %%
len(filenames_exp_21)
# Out:
# 432

# %% [markdown]
# ### Эксперимент №2.2

# %%
filenames_exp_22 = generate_filenames(
    {
        "expnum": ["exp22"],
        "models": ["d", "f", "g"],
        "distances": ["a", "b", "c"],
        "positions": ["1a", "1b", "1c", "2a", "2b", "2c", "3a", "3b", "3c"],
        "background": ["x"],
        "faces": ["a2", "d", "e"],
        "devices": ["a", "b"],
    }
)

# %%
filenames_exp_22
# Out:
# ['exp22_d_a_1a_x_a2_a.jpg',
#  'exp22_d_a_1a_x_a2_b.jpg',
#  'exp22_d_a_1a_x_d_a.jpg',
#  'exp22_d_a_1a_x_d_b.jpg',
#  'exp22_d_a_1a_x_e_a.jpg',
#  'exp22_d_a_1a_x_e_b.jpg',
#  'exp22_d_a_1b_x_a2_a.jpg',
#  'exp22_d_a_1b_x_a2_b.jpg',
#  'exp22_d_a_1b_x_d_a.jpg',
#  'exp22_d_a_1b_x_d_b.jpg',
#  'exp22_d_a_1b_x_e_a.jpg',
#  'exp22_d_a_1b_x_e_b.jpg',
#  'exp22_d_a_1c_x_a2_a.jpg',
#  'exp22_d_a_1c_x_a2_b.jpg',
#  'exp22_d_a_1c_x_d_a.jpg',
#  'exp22_d_a_1c_x_d_b.jpg',
#  'exp22_d_a_1c_x_e_a.jpg',
#  'exp22_d_a_1c_x_e_b.jpg',
#  'exp22_d_a_2a_x_a2_a.jpg',
#  'exp22_d_a_2a_x_a2_b.jpg',
#  'exp22_d_a_2a_x_d_a.jpg',
#  'exp22_d_a_2a_x_d_b.jpg',
#  'exp22_d_a_2a_x_e_a.jpg',
#  'exp22_d_a_2a_x_e_b.jpg',
#  'exp22_d_a_2b_x_a2_a.jpg',
#  'exp22_d_a_2b_x_a2_b.jpg',
#  'exp22_d_a_2b_x_d_a.jpg',
#  'exp22_d_a_2b_x_d_b.jpg',
#  'exp22_d_a_2b_x_e_a.jpg',
#  'exp22_d_a_2b_x_e_b.jpg',
#  'exp22_d_a_2c_x_a2_a.jpg',
#  'exp22_d_a_2c_x_a2_b.jpg',
#  'exp22_d_a_2c_x_d_a.jpg',
#  'exp22_d_a_2c_x_d_b.jpg',
# ...

# %%
len(filenames_exp_22)
# Out:
# 486
